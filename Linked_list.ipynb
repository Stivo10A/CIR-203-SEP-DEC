# %% [markdown]
# <a href="https://colab.research.google.com/github/Stivo10A/CIR-203-SEP-DEC/blob/main/Linked_list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def create_node(name, adm, grades):
    return {
        "name": name,
        "adm": adm,
        "grades": grades,
        "next": None
    }

def insert(head, name, adm, grades):
    new_node = create_node(name, adm, grades)

    if head is None:
        return new_node

    current = head
    while current["next"] is not None:
        current = current["next"]

    current["next"] = new_node
    return head

def display(head):
    current = head
    while current is not None:
        print("Name:", current["name"])
        print("Adm:", current["adm"])
        print("Grades:", current["grades"])
        print("-------------------")
        current = current["next"]

head = None

head = insert(head, "Stephen", "ADM0A1", [78, 85, 90])
head = insert(head, "Kevin", "ADM0A2", [65, 72, 81])
head = insert(head, "Miles", "ADM0A3", [88, 91, 94])

display(head)
# Out:
# Name: Stephen
# Adm: ADM0A1
# Grades: [78, 85, 90]
# -------------------
# Name: Kevin
# Adm: ADM0A2
# Grades: [65, 72, 81]
# -------------------
# Name: Miles
# Adm: ADM0A3
# Grades: [88, 91, 94]
# -------------------
